# %% [markdown]
# **
# Assignment 11 Solutions**
#
# **1. Given X be a discrete random variable with the following PMF**
#
# <img src="attachment:media/image1.png" style="width:0.60903in;height:0.47847in" />
#
# 1.  Find the range RX of the random variable X.
#
# 2.  Find P(X ≤ 0.5)
#
# 3.  Find P(0.25
#
# 4.  P(X = 0.2\|X\<0.6)
#
# In \[ \]:
#
# **2.Two equal and fair dice are rolled, and we observed two numbers X
# and Y.**
#
# 1.  Find RX, RY, and the PMFs of X and Y.
#
# 2.  Find P(X = 2,Y = 6).
#
# 3.  Find P(X>3\|Y = 2).
#
# 4.  If Z = X + Y. Find the range and PMF of Z.
#
# 5.  Find P(X = 4\|Z = 8).
#
# In \[ \]:
#
# **3. In an exam, there were 20 multiple-choice questions. Each question
# had 44 possible options. A student knew the answer to 10 questions, but
# the other 10 questions were unknown to him, and he chose answers
# randomly. If the student X's score is equal to the total number of
# correct answers, then find out the PMF of X. What is P(X>15)?**
#
# In \[ \]:
#
# **4. The number of students arriving at a college between a time
# interval is a Poisson random variable. On average, 10 students arrive
# per hour. Let Y be the number of students arriving from 10 am to 11:30
# am. What is P(10¶**
#
# In \[ \]:
#
# **5.Two independent random variables, X and Y,are given such that
# X\~Poisson(α) and Y\~Poisson(β). State a new random variable as Z = X +
# Y. Find out the PMF of Z.**
#
# In \[ \]:
#
# **6. There is a discrete random variable X with the pmf.**
#
# <img src="attachment:media/image2.png" style="width:1.4in;height:0.47847in" />
#
# **If we define a new random variable Y = (X + 1)2 then**
#
# 1.  Find the range of Y.
#
# 2.  Find the pmf of Y.
#
# **2.Assuming X is a continuous random variable with PDF**
#
# <img src="attachment:media/image3.png" style="width:1.04375in;height:0.21736in" />
#
# 1.  Find EX and Var(X).
#
# 2.  Find P(X ≥ 1/2).
#
# 3.  If X is a continuous random variable with pdf
#
# <img src="attachment:media/image4.png" style="width:0.55625in;height:0.33889in" />
#
# In \[ \]:
#
# X
